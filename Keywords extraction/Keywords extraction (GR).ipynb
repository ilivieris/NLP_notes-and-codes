# %%
doc = '''Αριθμ. 271840	
Επικύρωση του καθορισμού οριογραμμών υδατορέματος Σεσκουλιώτη στο Α/ Επιχειρηματικό Πάρκο (Ε.Π.) και Βιομηχανικό Πάρκο (ΒΙΟ.ΠΑ.) του Δήμου Βόλου της Περιφερειακής Ενότητας Μαγνησίας και Σποράδων, Περιφέρειας Θεσσαλίας.
Ο ΣΥΝΤΟΝΙΣΤΗΣ ΑΠΟΚΕΝΤΡΩΜΕΝΗΣ
ΔΙΟΙΚΗΣΗΣ ΘΕΣΣΑΛΙΑΣ - ΣΤΕΡΕΑΣ ΕΛΛΑΔΑΣ
Έχοντας υπόψη:
1. Το άρθρο 24 του Συντάγματος.
2. Το άρθρο 1 του ν. 1650/1986 (Α΄ 160).
3. Τον ν. 3852/2010 «Νέα Αρχιτεκτονική της Αυτοδιοίκησης και της Αποκεντρωμένης Διοίκησης -
Πρόγραμμα Καλλικράτης» (Α΄ 87).
4. Το π.δ. 138/2010 «Οργανισμός της Αποκεντρωμένης Διοίκησης Θεσσαλίας - Στερεάς Ελλάδας» (Α΄ 231).
5. Την υπ’ αρ. 92801/31-12-2020 (Υ.Ο.Δ.Δ. 1094) απόφαση του Υπουργείου Εσωτερικών περί αυτοδίκαιης απαλλαγής του Νικολάου Ντίτορα του Ευαγγέλου από τα καθήκοντα του Συντονιστή Αποκεντρωμένης Διοίκησης Θεσσαλίας - Στερεάς Ελλάδας και ορισμός ασκούντος καθήκοντα Συντονιστή Αποκεντρωμένης Διοίκησης Θεσσαλίας - Στερεάς Ελλάδας.
6. Τα άρθρα 28 και 28Α του ν. 4325/2015 «Εκδημοκρατισμός της Διοίκησης - Καταπολέμηση Γραφειοκρατίας και Ηλεκτρονική Διακυβέρνηση. Αποκατάσταση αδικιών και άλλες διατάξεις» (Α΄ 47), όπως το τελευταίο προστέθηκε με το άρθρο 24 του ν. 4368/2016 «Μέτρα για την επιτάχυνση του κυβερνητικού έργου και άλλες διατάξεις» (Α΄ 21).
7. Τον ν. 4258/2014 «Διαδικασία οριοθέτησης και ρυθμίσεις ρεμάτων για τα υδατορέματα - ρυθμίσεις πολεοδομικής νομοθεσίας και άλλες διατάξεις» (Α΄ 94).
8. Την υπ’ αρ. 14005/13-12-2017 κοινή υπουργική απόφαση «Τεχνικές προδιαγραφές σύνταξης του περιεχομένου του φακέλου οριοθέτησης κατ’ εφαρμογή της παρ. 5 του άρθρου 2 του ν. 4258/2014 -
Διευκρινίσεις για την εφαρμογή της διαδικασίας οριοθέτησης» (Β΄ 428).
9. Το υπ’ αρ. 116667/31-03-2021 (υπ’ αρ. 69661/
08-04-2021 ΔΙ.ΠΕ.ΧΩ.Σ.Θ.) έγγραφο της Διεύθυνσης Τεχνικών Έργων, Π.Ε. Μαγνησίας και Σποράδων, Περιφέρειας Θεσσαλίας, με το οποίο μας διαβιβάστηκε ελεγμένος και θεωρημένος ο φάκελος οριοθέτησης τμήματος του υδατορέματος Σεσκουλιώτη στο Α/ Επιχειρηματικό Πάρκο (Ε.Π.) και Βιομηχανικό Πάρκο (ΒΙΟ.ΠΑ.) Βόλου, του Δήμου Βόλου, της Π.Ε. Μαγνησίας και Σποράδων, όπως συντάχτηκε για λογαριασμό της ΕΤΒΑ ΒΙ.ΠΕ. Α.Ε., από την ΤΕΧΝΙΚΗ ΕΤΑΙΡΕΙΑ ΜΕΛΕΤΩΝ ΧΩΡΟΒΑΤΗΣ ΑΝΩΝΥΜΗ ΕΤΑΙΡΊΑ με δ.τ. «ΧΩΡΟΒΑΤΗΣ Α.Ε.», με νόμιμο κοινό Εκπρόσωπο τον ΛΥΜΠΕΡΑΚΗ ΙΩΑΝΝΗ.
10. Την υπό στοιχεία ΥΠΠΟΑ161337/25-05-2021 γνωμοδότηση της Εφορίας Αρχαιοτήτων Μαγνησίας σχετικά με τη «μελέτη οριστικής οριοθέτησης του ρέματος Σεσκουλιώτη στο Α/ Επιχειρηματικό Πάρκο και ΒΙΟ.ΠΑ. Βόλου», σε απάντηση του υπ’ αρ. 125508/07-04-2021 εγγράφου της Διεύθυνσης Τεχνικών Έργων, Π.Ε. Μαγνησίας και Σποράδων, Περιφέρειας Θεσσαλίας για γνωμοδότηση της παραπάνω μελέτης, σύμφωνα με την οποία «… σε περίπτωση που στο μέλλον προτίθεστε να προβείτε σε εργασίες τεχνικής φύσεως, θα πρέπει να κατατεθεί στην Υπηρεσία ο σχετικός φάκελος, ώστε να χορηγηθεί η σχετική άδεια, με την οποία θα τεθούν και οι προβλεπόμενοι από τον ν. 3028/2002 όροι».
11. Την υπ’ αρ. 138260/06-07-2021 (υπ’ αρ. 138433/
07-07-2021 ΔΙ.ΠΕ.ΧΩ.Σ.Θ.) θετική γνωμοδότηση της Διεύθυνσης Υδάτων Θεσσαλίας της Α.Δ.Θ.Στ.Ε, επί της «Μελέτης οριστικής οριοθέτησης τμήματος του ρέματος «Σεσκουλιώτης» στο Α/ Επιχειρηματικό Πάρκο και Βιομηχανικό Πάρκο Βόλου στη Δ.Κ. Διμηνίου της Δ.Ε., Αισωνίας Δήμου Βόλου, Π.Ε. Μαγνησίας, της Περιφέρειας Θεσσαλίας».
12. Την υπ’ αρ. 119782/10-06-2021 (υπ’ αρ. 119785/
16-06-2021 ΔΙ.ΠΕ.ΧΩ.Σ.Θ.) γνωμοδότηση του Δασαρχείου Βόλου της Α.Δ.Θ.Στ.Ε. για την «Μελέτη οριστικής οριοθέτησης του ρέματος «Σεσκουλιώτης» στο Α/ Επιχειρηματικό Πάρκο και Βιομηχανικό Πάρκο του Δήμου Βόλου της Π.Ε. Μαγνησίας», σύμφωνα με την οποία «………. κατά την κατασκευή έργων - εργασιών και παρεμβάσεων στις εκτάσεις που προστατεύονται από την δασική νομοθεσία, θα προηγείται ανάλογο αίτημα προς την Υπηρεσία για την έγκριση υλοτομίας και απομάκρυνσης των τυχόν δασικών δέντρων και θάμνων».
13. Την υπ’ αρ. 231/2021 (ΑΔΑ: Ω204Ω96-ΟΛ4) ομόφωνη απόφαση του Δήμου Βόλου σχετικά με τη «Μελέτη οριστικής οριοθέτησης τμήματος του ρέματος Σεσκουλιώτη στο Α/ Επιχειρηματικό Πάρκο και Βιομηχανικό Πάρκο του Δήμου Βόλου της Π.Ε. Μαγνησίας», που διαβιβάστηκε στη Διεύθυνση Περιβάλλοντος και Χωρικού Σχεδιασμού Θεσσαλίας με το υπ’ αρ. 6791/01-09-2021 (υπ’ αρ. 181403/07-09-2021 ΔΙ.ΠΕ.ΧΩ.Σ.Θ.) έγγραφο της Διεύθυνσης Υπηρεσίας Δόμησης του Δήμου Βόλου.
14. Την υπ’ αρ. 267831/16-12-2021 (ΑΔΑ: 6ΟΔΩΟΡ10-ΛΛΠ) απόφαση της Α.Δ.Θ.Στ.Ε./ΔΙ.ΠΕ.ΧΩ.Σ. Θεσσαλίας περί καθορισμού οριογραμμών υδατορέματος Σεσκουλιώτη στο Α/ Επιχειρηματικό Πάρκο (Ε.Π.) και Βιομηχανικό Πάρκο (ΒΙΟ.ΠΑ.) του Δήμου Βόλου της Περιφερειακής Ενότητας Μαγνησίας και Σποράδων, Περιφέρειας Θεσσαλίας.
15. Το γεγονός ότι από την απόφαση αυτή δεν προκαλείται δαπάνη σε βάρος του κρατικού προϋπολογισμού ή του προϋπολογισμού του οικείου ΟΤΑ.
και επειδή
Η αρμοδιότητα για την επικύρωση του καθορισμού των οριογραμμών υδατορέματος (οριοθέτηση) ανήκει στο Γενικό Γραμματέα και νυν Συντονιστή της οικείας Αποκεντρωμένης Διοίκησης, σύμφωνα με την παρ. 3.1 του άρθρου 3 του ν. 4258/2014 (Α΄ 94), αποφασίζουμε:
Την επικύρωση του καθορισμού οριογραμμών τμήματος του υδατορέματος Σεσκουλιώτη στο Α/ Επιχειρηματικό Πάρκο (Ε.Π.) και Βιομηχανικό Πάρκο (ΒΙΟ.ΠΑ.) Βόλου, του Δήμου Βόλου, της Π.Ε. Μαγνησίας και Σποράδων, με τις συντεταγμένες των κορυφών των πολυγωνικών τους γραμμών όπως αυτές σημειώνονται με μπλε γραμμή και αναπαρίσταται επί των τοπογραφικών διαγραμμάτων κλίμακας 1:500 (ΟΡΙΖΟΝΤΙΟΓΡΑΦΙΑ ΥΦΙΣΤΑΜΕΝΗΣ ΚΑΤΑΣΤΑΣΗΣ - ΓΡΑΜΜΕΣ ΠΛΗΜΜΥΡΑΣ - ΠΡΟΤΑΣΗ ΚΑΘΟΡΙΣΜΟΥ ΟΡΙΟΓΡΑΜΜΩΝ, Αριθμός Σχεδίων: α) ΟΡ.1, από Χ.Θ. 0+000,00 (Δ1) έως Χ.Θ. 0+962,68 (Δ49), β) ΟΡ.2, από Χ.Θ. 0+962,68 (Δ49) έως Χ.Θ. 1+959,90 (Δ86), γ) ΟΡ.3, από Χ.Θ 1+959,90 (Δ86) έως Χ.Θ. 2+967,55 (Δ118), που προέκυψαν από την υδραυλική μελέτη, η οποία συντάχθηκε από την ΤΕΧΝΙΚΗ ΕΤΑΙΡΕΙΑ ΜΕΛΕΤΩΝ ΧΩΡΟΒΑΤΗΣ ΑΝΩΝΥΜΗ ΕΤΑΙΡΊΑ με δ.τ. «ΧΩΡΟΒΑΤΗΣ Α.Ε.» και ελέγχθηκαν και θεωρήθηκαν αρμοδίως από την Δ/νση Τεχνικών Έργων, Π.Ε. Μαγνησίας και Σποράδων, Περιφέρειας Θεσσαλίας.
Η απόφαση αυτή να δημοσιευθεί στην Εφημερίδα της Κυβερνήσεως μαζί με τα σχέδια με τίτλο «ΟΡΙΖΟΝΤΙΟΓΡΑΦΙΑ ΥΦΙΣΤΑΜΕΝΗΣ ΚΑΤΑΣΤΑΣΗΣ - ΓΡΑΜΜΕΣ ΠΛΗΜΜΥΡΑΣ - ΠΡΟΤΑΣΗ ΚΑΘΟΡΙΣΜΟΥ ΟΡΙΟΓΡΑΜΜΩΝ» και με Αριθμό Σχεδίων: α) ΟΡ.1, από Χ.Θ. 0+000,00 (Δ1) έως Χ.Θ. 0+962,68 (Δ49) β) ΟΡ.2, από Χ.Θ. 0+962,68 (Δ49) έως Χ.Θ. 1+959,90 (Δ86) γ) ΟΡ.3, από Χ.Θ 1+959,90 (Δ86) έως Χ.Θ. 2+967,55 (Δ118),
Η ισχύς της απόφασης αυτής αρχίζει από τη δημοσίευσή της στην Εφημερίδα της Κυβερνήσεως.
Η απόφαση αυτή να αναρτηθεί στο διαδίκτυο σύμφωνα με τον ν. 4727/2020 «Ψηφιακή Διακυβέρνηση (Ενσωμάτωση στην Ελληνική Νομοθεσία της οδηγίας (ΕΕ) 2016/2102 και της οδηγίας (ΕΕ) 2019/1024) -
Ηλεκτρονικές Επικοινωνίες (Ενσωμάτωση στο Ελληνικό Δίκαιο της οδηγίας (ΕΕ) 2018/1972) και άλλες διατάξεις» (Α΄ 184).
Η απόφαση αυτή να δημοσιευθεί στην Εφημερίδα της Κυβερνήσεως.
Λάρισα, 22 Δεκεμβρίου 2021'''

# %% [markdown]
# ### Approach 1

# %%
import yake

kw_extractor = yake.KeywordExtractor()
keywords = kw_extractor.extract_keywords(doc)
for kw in keywords:
  print(kw)
# Out:
# ('του Δήμου Βόλου', 0.0050631440031533555)
# ('και Βιομηχανικό Πάρκο', 0.005436483656496859)
# ('Επιχειρηματικό Πάρκο', 0.006816173157457062)
# ('Δήμου Βόλου', 0.007419544084054212)
# ('Επιχειρηματικό Πάρκο και', 0.008380702033801594)
# ('Μαγνησίας και Σποράδων', 0.008391336172799557)
# ('Αποκεντρωμένης Διοίκησης Θεσσαλίας', 0.008430308022242346)
# ('Βιομηχανικό Πάρκο', 0.008733474452212408)
# ('Δήμου Βόλου της', 0.010495353493403017)
# ('Πάρκο και Βιομηχανικό', 0.012685128531826005)
# ('Την', 0.012703436995417238)
# ('του', 0.013191486174524703)
# ('και', 0.013517149112227424)
# ('Πάρκο', 0.013748857646761198)
# ('της', 0.014773457331675583)
# ('Αποκεντρωμένης Διοίκησης', 0.015620981426023035)
# ('Πάρκο του Δήμου', 0.01623452025252823)
# ('Βιομηχανικό Πάρκο Βόλου', 0.01695568751386992)
# ('του Δήμου', 0.017395628643742268)
# ('Περιφέρειας Θεσσαλίας', 0.01743306828658345)

# %% [markdown]
# ### Approach 2

# %%
import spacy
import pytextrank

# load a spaCy model, depending on language, scale, etc.
nlp = spacy.load("el_core_news_sm")
# add PyTextRank to the spaCy pipeline
nlp.add_pipe("textrank")
result = nlp(doc)

# examine the top-ranked phrases in the document
for phrase in result._.phrases[:10]:
    print(phrase.text)
# Out:
# Χ.Θ
# Αποκεντρωμένης Διοίκησης Θεσσαλίας
# Αποκεντρωμένης Διοίκησης
# Βιομηχανικό Πάρκο
# Θεσσαλίας
# Ελληνική Νομοθεσία
# έως Χ.Θ
# ΕΕ
# Δήμου Βόλου
# Αριθμό Σχεδίων

# %% [markdown]
# ### Approach 3

# %%
import spacy
import subprocess
from string import punctuation

def extract_keywords(nlp, sequence, special_tags : list = None):
    """ Takes a Spacy core language model,
    string sequence of text and optional
    list of special tags as arguments.
    
    If any of the words in the string are 
    in the list of special tags they are immediately 
    added to the result.  
    
    Arguments:
        sequence {str} -- string sequence to have keywords extracted from
    
    Keyword Arguments:
        tags {list} --  list of tags to be automatically added (default: {None})
    
    Returns:
        {list} -- list of the unique keywords extracted from a string
    """    
    result = []

    # custom list of part of speech tags we are interested in
    # we are interested in proper nouns, nouns, and adjectives
    # edit this list of POS tags according to your needs. 
    pos_tag = ['PROPN','NOUN','ADJ']

    # create a spacy doc object by calling the nlp object on the input sequence
    doc = nlp(sequence.lower())

    # if special tags are given and exist in the input sequence
    # add them to results by default
    if special_tags:
        tags = [tag.lower() for tag in special_tags]
        for token in doc:
            if token.text in tags:
                result.append(token.text)
    
    for chunk in doc.noun_chunks:
        final_chunk = ""
        for token in chunk:
            if (token.pos_ in pos_tag):
                final_chunk =  final_chunk + token.text + " "
        if final_chunk:
            result.append(final_chunk.strip())


    for token in doc:
        if (token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if (token.pos_ in pos_tag):
            result.append(token.text)
    return list(set(result))

 
nlp = spacy.load("el_core_news_sm")

extract_keywords(nlp,doc)
# Out:
# ['8. αρ. κοινή υπουργική απόφαση τεχνικές προδιαγραφές',
#  'απόφαση δήμου',
#  '5.',
#  'καθήκοντα',
#  'θετική',
#  'υδραυλική μελέτη',
#  'α.δ.θ.στ.ε',
#  'απομάκρυνσης',
#  'γενικό γραμματέα',
#  'δεκεμβρίου',
#  '000,00',
#  'σεσκουλιώτη',
#  'εφορίας',
#  'συντονιστης',
#  'νομοθεσίας',
#  'γραμμες πλημμυρας',
#  'θεσσαλίας καθορισμού',
#  'ελλαδας',
#  'μελέτη',
#  '2.',
#  'νυν',
#  'αποκατάσταση',
#  '1094',
#  'υφισταμενης',
#  'ελλάδας',
#  'ηλεκτρονική',
#  'αριθμό',
#  'αποκεντρωμένης',
#  'περιφέρειας θεσσαλίας',
#  'α.δ.θ.στ.ε./δι.πε.χω.ς',
#  'αρ. 231/2021 ω204ω96-ολ4',
#  'περιφερειακής',
#  'ασκούντος',
#  'ψηφιακή',
#  'υλοτομίας',
#  'εφημερίδα κυβερνήσεως',
#  'ορισμός',
#  'περιεχομένου',
#  'μελετων',
#  'βόλου',
#  'καθορισμου',
#  'δ118',
#  'οριοθέτησης',
#  '06-2021',
#  'διεύθυνσης',
#  'διατάξεις',
#  'έγγραφο διεύθυνσης υπηρεσίας',
#  'στερεας ελλαδας',
#  'άρθρα',
#  'υπηρεσία',
#  'δ.ε',
#  'έγκριση',
#  'περιβάλλοντος',
#  'οικείου',
#  'επιτάχυνση',
# ...
